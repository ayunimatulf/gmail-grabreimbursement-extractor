# %%
from google_auth_oauthlib.flow import InstalledAppFlow

SCOPES = ["https://www.googleapis.com/auth/gmail.readonly"]

flow = InstalledAppFlow.from_client_secrets_file(
    "cred.json",
    SCOPES
)

creds = flow.run_local_server(port=0)

with open("token.json", "w") as f:
    f.write(creds.to_json())

print("Authentication successful")
# Out:
# Please visit this URL to authorize this application: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=760396285080-kophee8q27vpr2pt2bhutm4e19ocj3d5.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A13334%2F&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fgmail.readonly&state=spTQuBE8ZW5NyQKyahGyQTKYWQimic&code_challenge=ulL-5KOHMuZEKZG_bACeu3in13MJcp88D06OZSmLxMM&code_challenge_method=S256&access_type=offline
# Authentication successful
